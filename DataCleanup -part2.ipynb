# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', 300)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
df=pd.read_csv("MCI_data2014_2019_version1.csv")

# %%
df.head()
# Out:
#               X             Y  Index_ event_unique_id          occurrencedate            reporteddate premisetype  ucr_code  ucr_ext             offence  reportedyear reportedmonth  reportedday  reporteddayofyear reporteddayofweek  reportedhour  occurrenceyear occurrencemonth  occurrenceday  occurrencedayofyear occurrencedayofweek  occurrencehour              MCI Division  Hood_ID           Neighbourhood       Long        Lat  ObjectId  Employment rate  Unemployment rate  Unsuitable rate  population  Postsecondary  Postsecondary rate  income  density
# ...

# %%
df.shape
# Out:
# (205321, 37)

# %%
severe_crime_list=["Assault",  "Robbery"]
df["severe"]=np.where(df['MCI'].isin(severe_crime_list), 1, 0)
df.head()
# Out:
#               X             Y  Index_ event_unique_id          occurrencedate            reporteddate premisetype  ucr_code  ucr_ext             offence  reportedyear reportedmonth  reportedday  reporteddayofyear reporteddayofweek  reportedhour  occurrenceyear occurrencemonth  occurrenceday  occurrencedayofyear occurrencedayofweek  occurrencehour              MCI Division  Hood_ID           Neighbourhood       Long        Lat  ObjectId  Employment rate  Unemployment rate  Unsuitable rate  population  Postsecondary  Postsecondary rate  income  density  severe
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205321 entries, 0 to 205320
# Data columns (total 38 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   X                    205321 non-null  float64
#  1   Y                    205321 non-null  float64
#  2   Index_               205321 non-null  int64
#  3   event_unique_id      205321 non-null  object
#  4   occurrencedate       205321 non-null  object
#  5   reporteddate         205321 non-null  object
#  6   premisetype          205321 non-null  object
#  7   ucr_code             205321 non-null  int64
#  8   ucr_ext              205321 non-null  int64
#  9   offence              205321 non-null  object
#  10  reportedyear         205321 non-null  int64
#  11  reportedmonth        205321 non-null  object
#  12  reportedday          205321 non-null  int64
#  13  reporteddayofyear    205321 non-null  int64
#  14  reporteddayofweek    205321 non-null  object
# ...

# %%
df['occurrenceday'] = df['occurrenceday'].astype('int32') 
df['occurrencedayofyear'] = df['occurrencedayofyear'].astype('int32')

# %%
df['target'] = pd.factorize(df["MCI"])[0]

# %%
df.head(20)
# Out:
#                X             Y  Index_ event_unique_id          occurrencedate            reporteddate premisetype  ucr_code  ucr_ext                   offence  reportedyear reportedmonth  reportedday  reporteddayofyear reporteddayofweek  reportedhour  occurrenceyear occurrencemonth  occurrenceday  occurrencedayofyear occurrencedayofweek  occurrencehour              MCI Division  Hood_ID                        Neighbourhood       Long        Lat  ObjectId  Employment rate  Unemployment rate  Unsuitable rate  population  Postsecondary  Postsecondary rate  income  density  severe  target
# ...

# %%
df['month'] = pd.factorize(df["occurrencemonth"])[0]

# %%
df['day'] = pd.factorize(df["occurrencedayofweek"])[0]

# %%
df['premise_type'] = pd.factorize(df["premisetype"])[0]

# %%
df
# Out:
#                    X             Y  Index_ event_unique_id          occurrencedate            reporteddate premisetype  ucr_code  ucr_ext                 offence  reportedyear reportedmonth  reportedday  reporteddayofyear reporteddayofweek  reportedhour  occurrenceyear occurrencemonth  occurrenceday  occurrencedayofyear occurrencedayofweek  occurrencehour              MCI Division  Hood_ID               Neighbourhood       Long        Lat  ObjectId  Employment rate  Unemployment rate  Unsuitable rate  population  Postsecondary  Postsecondary rate  income  density  severe  target  month  day  premise_type
# ...

# %%
#make a dummy variable for district and type of crime
#dummydf=pd.get_dummies(df,columns=["premisetype","Hood_ID"])
#dummydf=dummydf.join(df[["premisetype","Hood_ID"]])

# %%
#dummydf

# %%
df.to_csv("MCI_data2014_2019_version2.csv", index = False)
